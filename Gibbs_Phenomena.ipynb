# %% [markdown]
# <a href="https://colab.research.google.com/github/AlirezaAhadipour/Fourier-Transform/blob/main/Gibbs_Phenomena.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define parameters
dx = 0.01
L = 2 * np.pi
x = np.arange(0, L+dx, dx)
n = len(x)
n_quart = int(np.floor(n/4))

# Define rectangle signal
f = np.zeros_like(x)
f[n_quart: 3*n_quart] = 1

# Fourier Series
A0 = np.sum(f * np.ones_like(x)) * dx * 2 / L
fFS = A0/2 * np.ones_like(f)

for k in range(1, 101):
  Ak = np.sum(f * np.cos(2*np.pi*k*x/L)) * dx * 2 / L
  Bk = np.sum(f * np.sin(2*np.pi*k*x/L)) * dx * 2 / L
  fFS = fFS + (Ak * np.cos(2*k*np.pi*x/L)) + (Bk * np.sin(2*k*np.pi*x/L))

# Plot
plt.plot(x, f, color='k', linewidth=2)
plt.plot(x, fFS, color='r', alpha=0.5)
plt.show()
